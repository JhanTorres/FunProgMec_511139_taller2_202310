# %%
#Jhan David Torres 
#000511139
#jhan.torres@upb.edu.co

#Solicita información personal

Residencia = input("¿Dónde vive? (Montería o fuera de el): ")
Estrato = int(input("¿Cuál es el estrato socioeconómico? (1, 2, 3, 4, 5 o 6): "))
Edad = int(input("¿Cuál es la edad?: "))
Promedio.ponderado = float(input("¿Cuál es el promedio académico ponderado del semestre? (de 0 a 5): "))
auxilio.transporte = 0
auxilio.alimentacion = 0
              
#Calcular apoyo del transporte Chocolove

if Estrato == 1:
    if Edad < 18:
        auxilio.transporte = 65000
    else:
        auxilio.transporte = 50000
elif Estrato == 2:
    if Edad < 18:
        auxilio.transporte = 45000
    else:
        auxilio.transporte = 30000
elif Estratp == 3:
    if Edad < 18:
        auxilio.transporte = 35000
    else: 
        auxilio.transporte = 20000
        

# Calcular apoyo de alimentación Chocolove
              
costo_alimentacion = 20000 * 20
if Estrato == 1:
    if Edad < 18:
        auxilio.alimentacion = costo.alimentacion * 0.9
    else:
        auxilio.alimentacion = costo.alimentacion * 0.7
elif Estrato == 2:
    if Edad < 18:
        auxilio.alimentacion = costo.alimentacion * 0.7
    else:
        auxilio.alimentacion = costo.alimentacion * 0.5
elif Estrato == 3:
    if Edad < 18:
        auxilio.alimentacion = costo.alimentacion * 0.5
    else:
        auxilio.alimentacion = costo.alimentacion * 0.3

# Calcular costo total de transporte
              
if lugar.residencia == "Montería":
    costo.transporte = 2800 * 2 * 20 - auxilio.transporte * 4
else:
    costo.transporte = 3500 * 2 * 20 - auxilio.transporte * 4

# Calcular total de alimentación
              
costo.alimentacion.total = costo.alimentacion - auxilio.alimentacion * 4

# Calcular total de matrícula
              
costo.matricula.total = 5000000 - 5000000 * (promedio.ponderado - 4.0) / 1.0

if promedio.ponderado >= 4.8:
    costo.matricula.total *= 0
elif promedio.ponderado >= 4.5:
    costo.matricula.total *= 0.3
elif promedio.ponderado >= 4.0:
    costo.matricula.total *= 0.6
else:
    costo.matricula.total *= 1

# Calcular gasto total mensual

gasto.total.mensual = (costo.transporte + costo.alimentacion)

#Print gasto total
print("El gasto total mensual es de $", gasto.total.mensual)
